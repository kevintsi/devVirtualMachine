# %%
import pandas as pds
from sklearn.model_selection import train_test_split

# %%
class DataHandler:

    def __init__(self):
        print("Initialization")
        self.df_listings_final = None
        self.df_price_availability = None
        self.df_merge = None

    def get_data(self):
        print("Get data from bucket")
        self.df_listings_final = pds.read_csv("https://storage.googleapis.com/h3-data/listings_final.csv", sep=";")
        self.df_price_availability = pds.read_csv("https://storage.googleapis.com/h3-data/price_availability.csv", sep=";")

    def group_data(self):
        # merge
        print("Data merged") 
        self.df_merge = pds.merge(self.df_price_availability.groupby('listing_id')['local_price'].mean(), self.df_listings_final, on='listing_id')

    def get_process_data(self):
        self.get_data()
        self.group_data()

# %%
d = DataHandler()
# Out:
# Initialization

# %%
d.get_process_data()
# %time
# Out:
# Get data from bucket
# Data merged
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.48 µs

# %%
d.df_merge.head()
# Out:
#    listing_id  local_price  Unnamed: 0                                name  \
# 0       56093   170.000000          12         Beau duplex dans le Marais
# 1       57207    49.952756          13            Belle Chambre pour court
# 2      114543   107.374026          19   Charming 1bdr 55m² - Eiffel Tower
# 3      149534   169.000000           9  GREAT WARM FULL APT LE HAUT MARAIS
# 4      164255    75.876209          28  Perfect place in Le Marais - Paris
#
#            type   city       neighborhood   latitude  longitude  \
# 0   entire_home  Paris  3e arrondissement  48.867284   2.358431
# 1  private_room  Paris          Vaugirard  48.846184   2.304455
# 2   entire_home  Paris                NaN  48.849530   2.290219
# 3   entire_home  Paris                NaN  48.866360   2.361844
# 4   entire_home  Paris  3e arrondissement  48.861398   2.364299
#
#    person_capacity  beds  bedrooms  bathrooms  is_rebookable  is_new_listing  \
# 0                4     2         1        1.0          False           False
# 1                2     1         1        1.0          False           False
# 2                2     1         1        1.0          False           False
# 3                4     2         1        1.0          False           False
# 4                4     2         1        1.0          False           False
#
#    is_fully_refundable  is_host_highly_rated  is_business_travel_ready  \
# 0                 True                  True                     False
# 1                 True                 False                     False
# 2                 True                  True                     False
# 3                 True                  True                     False
# 4                 True                 False                     False
#
#    pricing_weekly_factor  pricing_monthly_factor
# 0                   0.88                     1.0
# 1                   0.87                     1.0
# 2                   0.90                     0.9
# 3                   1.00                     0.4
# 4                   1.00                     1.0

# %%
d.df_merge.tail()
# Out:
#      listing_id  local_price  Unnamed: 0  \
# 994    28684174   725.175781         662
# 995    28709644   475.000000         745
# 996    28751412   117.000000          88
# 997    28774896   156.397468         159
# 998    28792796    49.184211         998
#
#                                                   name          type   city  \
# 994  Chambre familiale vue jardin avec petit-déjeun...  private_room  Paris
# 995                 LORD BYRON-SPACE& STYLE IN 8TH EME   entire_home  Paris
# 996                         Malesherbes Monceau Monsen   entire_home  Paris
# 997      5 min to invalides and 10 min to eiffel tower   entire_home  Paris
# 998                  Appartement 3 chambres madeleine.   entire_home  Paris
#
#                     neighborhood   latitude  longitude  person_capacity  beds  \
# 994                       Ternes  48.879223   2.292382                5     0
# 995               Champs-Elysées  48.872202   2.298349                4     2
# 996                      Monceau  48.880923   2.314568                2     1
# 997  Invalides - Ecole Militaire  48.852915   2.314519                2     1
# 998          Madeleine - Vendôme  48.870109   2.321475                6     4
#
#      bedrooms  bathrooms  is_rebookable  is_new_listing  is_fully_refundable  \
# 994         1        1.0          False            True                 True
# 995         1        1.0          False            True                 True
# 996         0        1.0          False            True                 True
# 997         1        1.0          False            True                 True
# 998         2        1.5          False            True                 True
#
#      is_host_highly_rated  is_business_travel_ready  pricing_weekly_factor  \
# 994                 False                     False                    1.0
# 995                 False                     False                    1.0
# 996                 False                     False                    1.0
# 997                 False                     False                    1.0
# 998                 False                     False                    1.0
#
#      pricing_monthly_factor
# 994                     1.0
# 995                     1.0
# 996                     1.0
# 997                     1.0
# 998                     1.0

# %%
d.df_merge.shape
# Out:
# (999, 20)

# %%
class FeatureRecipe:
    
    def __init__(self, data: pds.DataFrame):
        print("FeatureRecipe starts...")
        self.df = data
        self.cate = []
        self.floa = []
        self.intt = []
        print("End of FeatureRecipe initialisation\n")
    
    def separate_variable_types(self) -> None:
        print("Separate variable types starts...")
        for col in self.df.columns:
            if self.df[col].dtypes == int:
                self.intt.append(self.df[col])
            elif self.df[col].dtypes == float:
                self.floa.append(self.df[col])
            else:
                self.cate.append(self.df[col])
        print("Separate variable types end...")
        print ("Dataset number of columns : {} \nnumber of discreet values : {} \nnumber of continuous values : {} \nnumber of others : {} \ntotal size : {}\n".format(len(self.df.columns),
        len(self.intt),len(self.floa),len(self.cate),len(self.intt)+len(self.floa)+len(self.cate) ))
        
    def drop_uselessf(self):
        print("Drop useless feature start...")
        
        if "Unnamed: 0" in self.df.columns:
            self.df.drop("Unnamed: 0", axis=1, inplace=True)
            
        for col in self.df.columns:
            if self.df[col].isna().sum() == len(self.df[col]):
                self.df.drop([col], axis=1, inplace=True)
                
        print("Drop useless feature end...")
        print("Number columns remaining {}\n".format(len(self.df.columns)))
        
    def deal_duplicate(self):
        print("Deal duplicate start...")
        dropped_duplicates = self.df.drop_duplicates(inplace=True)
        print("Dropped duplicates : {}".format(dropped_duplicates))
        print("Deal duplicate end...")
    
    def drop_nanp(self, threshold: float):
        dropped = 0
        print("Drop columns with {} percentage of NAN".format(threshold))
        self.get_duplicates()
              
        for col in self.df.columns:
            if self.df[col].isna().sum() / self.df.shape[0] >= threshold:
                self.df.drop([col], axis=1, inplace=True)
                dropped+=1
              
        print("Number of columns dropped : {}\n".format(dropped))
    
    def get_duplicates(self):
        print("Get duplicates")
        
        for col in self.df.columns:
            for row in range(self.df.shape[0]):
                
              
    def deal_dtime(self):
        pass
    
    def prepare_data(self, threshold: float):
        self.drop_uselessf()
        self.separate_variable_types()
        self.deal_duplicate()
        self.drop_nanp(threshold)
        self.deal_dtime()

# %%
frecipe = FeatureRecipe(d.df_merge)
# Out:
# FeatureRecipe starts...
# End of FeatureRecipe initialisation

# %%
frecipe.prepare_data(3)
# Out:
# Drop useless feature start...
# Drop useless feature end...
# Number columns remaining 19
#
# Separate variable types starts...
# Separate variable types end...
# Dataset number of columns : 19
# number of discreet values : 4
# number of continuous values : 6
# number of others : 9
# total size : 19
#
# Deal duplicate start...
# Dropped duplicates : None
# Deal duplicate end...
# Drop columns with 3 percentage of NAN
# Get duplicates
# listing_id , 0
# listing_id , 1
# listing_id , 2
# listing_id , 3
# listing_id , 4
# listing_id , 5
# listing_id , 6
# listing_id , 7
# listing_id , 8
# listing_id , 9
# listing_id , 10
# listing_id , 11
# listing_id , 12
# listing_id , 13
# listing_id , 14
# listing_id , 15
# listing_id , 16
# listing_id , 17
# listing_id , 18
# listing_id , 19
# listing_id , 20
# listing_id , 21
# listing_id , 22
# listing_id , 23
# listing_id , 24
# listing_id , 25
# listing_id , 26
# listing_id , 27
# listing_id , 28
# listing_id , 29
# listing_id , 30
# listing_id , 31
# listing_id , 32
# listing_id , 33
# listing_id , 34
# listing_id , 35
# listing_id , 36
# listing_id , 37
# listing_id , 38
# listing_id , 39
# listing_id , 40
# listing_id , 41
# listing_id , 42
# listing_id , 43
# listing_id , 44
# listing_id , 45
# listing_id , 46
# listing_id , 47
# listing_id , 48
# listing_id , 49
# listing_id , 50
# listing_id , 51
# listing_id , 52
# listing_id , 53
# listing_id , 54
# listing_id , 55
# listing_id , 56
# listing_id , 57
# listing_id , 58
# listing_id , 59
# listing_id , 60
# listing_id , 61
# listing_id , 62
# listing_id , 63
# listing_id , 64
# listing_id , 65
# listing_id , 66
# listing_id , 67
# listing_id , 68
# listing_id , 69
# listing_id , 70
# listing_id , 71
# listing_id , 72
# listing_id , 73
# listing_id , 74
# listing_id , 75
# listing_id , 76
# listing_id , 77
# listing_id , 78
# listing_id , 79
# listing_id , 80
# listing_id , 81
# listing_id , 82
# listing_id , 83
# listing_id , 84
# listing_id , 85
# listing_id , 86
# listing_id , 87
# listing_id , 88
# listing_id , 89
# listing_id , 90
# listing_id , 91
# listing_id , 92
# listing_id , 93
# listing_id , 94
# listing_id , 95
# listing_id , 96
# listing_id , 97
# listing_id , 98
# listing_id , 99
# listing_id , 100
# listing_id , 101
# listing_id , 102
# listing_id , 103
# listing_id , 104
# listing_id , 105
# listing_id , 106
# listing_id , 107
# listing_id , 108
# listing_id , 109
# listing_id , 110
# listing_id , 111
# listing_id , 112
# listing_id , 113
# listing_id , 114
# listing_id , 115
# listing_id , 116
# listing_id , 117
# listing_id , 118
# listing_id , 119
# listing_id , 120
# listing_id , 121
# listing_id , 122
# listing_id , 123
# listing_id , 124
# listing_id , 125
# listing_id , 126
# listing_id , 127
# listing_id , 128
# listing_id , 129
# listing_id , 130
# listing_id , 131
# listing_id , 132
# listing_id , 133
# listing_id , 134
# listing_id , 135
# listing_id , 136
# listing_id , 137
# listing_id , 138
# listing_id , 139
# listing_id , 140
# listing_id , 141
# listing_id , 142
# listing_id , 143
# listing_id , 144
# listing_id , 145
# listing_id , 146
# listing_id , 147
# listing_id , 148
# listing_id , 149
# listing_id , 150
# listing_id , 151
# listing_id , 152
# listing_id , 153
# listing_id , 154
# listing_id , 155
# listing_id , 156
# listing_id , 157
# listing_id , 158
# listing_id , 159
# listing_id , 160
# listing_id , 161
# listing_id , 162
# listing_id , 163
# listing_id , 164
# listing_id , 165
# listing_id , 166
# listing_id , 167
# listing_id , 168
# listing_id , 169
# listing_id , 170
# listing_id , 171
# listing_id , 172
# listing_id , 173
# listing_id , 174
# listing_id , 175
# listing_id , 176
# listing_id , 177
# listing_id , 178
# listing_id , 179
# listing_id , 180
# listing_id , 181
# listing_id , 182
# listing_id , 183
# listing_id , 184
# listing_id , 185
# listing_id , 186
# listing_id , 187
# listing_id , 188
# listing_id , 189
# listing_id , 190
# listing_id , 191
# listing_id , 192
# listing_id , 193
# listing_id , 194
# listing_id , 195
# listing_id , 196
# listing_id , 197
# listing_id , 198
# listing_id , 199
# listing_id , 200
# listing_id , 201
# listing_id , 202
# listing_id , 203
# listing_id , 204
# listing_id , 205
# listing_id , 206
# listing_id , 207
# listing_id , 208
# listing_id , 209
# listing_id , 210
# listing_id , 211
# listing_id , 212
# listing_id , 213
# listing_id , 214
# listing_id , 215
# listing_id , 216
# listing_id , 217
# listing_id , 218
# listing_id , 219
# listing_id , 220
# listing_id , 221
# listing_id , 222
# listing_id , 223
# listing_id , 224
# listing_id , 225
# listing_id , 226
# listing_id , 227
# listing_id , 228
# listing_id , 229
# listing_id , 230
# listing_id , 231
# listing_id , 232
# listing_id , 233
# listing_id , 234
# listing_id , 235
# listing_id , 236
# listing_id , 237
# listing_id , 238
# listing_id , 239
# listing_id , 240
# listing_id , 241
# listing_id , 242
# listing_id , 243
# listing_id , 244
# listing_id , 245
# listing_id , 246
# listing_id , 247
# listing_id , 248
# listing_id , 249
# listing_id , 250
# listing_id , 251
# listing_id , 252
# listing_id , 253
# listing_id , 254
# listing_id , 255
# listing_id , 256
# listing_id , 257
# listing_id , 258
# listing_id , 259
# listing_id , 260
# listing_id , 261
# listing_id , 262
# listing_id , 263
# listing_id , 264
# listing_id , 265
# listing_id , 266
# listing_id , 267
# listing_id , 268
# listing_id , 269
# listing_id , 270
# listing_id , 271
# listing_id , 272
# listing_id , 273
# listing_id , 274
# listing_id , 275
# listing_id , 276
# listing_id , 277
# listing_id , 278
# listing_id , 279
# listing_id , 280
# listing_id , 281
# listing_id , 282
# listing_id , 283
# listing_id , 284
# listing_id , 285
# listing_id , 286
# listing_id , 287
# listing_id , 288
# listing_id , 289
# listing_id , 290
# listing_id , 291
# listing_id , 292
# listing_id , 293
# listing_id , 294
# listing_id , 295
# listing_id , 296
# listing_id , 297
# listing_id , 298
# listing_id , 299
# listing_id , 300
# listing_id , 301
# listing_id , 302
# listing_id , 303
# listing_id , 304
# listing_id , 305
# listing_id , 306
# listing_id , 307
# listing_id , 308
# listing_id , 309
# listing_id , 310
# listing_id , 311
# listing_id , 312
# listing_id , 313
# listing_id , 314
# listing_id , 315
# listing_id , 316
# listing_id , 317
# listing_id , 318
# listing_id , 319
# listing_id , 320
# listing_id , 321
# listing_id , 322
# listing_id , 323
# listing_id , 324
# listing_id , 325
# listing_id , 326
# listing_id , 327
# listing_id , 328
# listing_id , 329
# listing_id , 330
# listing_id , 331
# listing_id , 332
# listing_id , 333
# listing_id , 334
# listing_id , 335
# listing_id , 336
# listing_id , 337
# listing_id , 338
# listing_id , 339
# listing_id , 340
# listing_id , 341
# listing_id , 342
# listing_id , 343
# listing_id , 344
# listing_id , 345
# listing_id , 346
# listing_id , 347
# listing_id , 348
# listing_id , 349
# listing_id , 350
# listing_id , 351
# listing_id , 352
# listing_id , 353
# listing_id , 354
# listing_id , 355
# listing_id , 356
# listing_id , 357
# listing_id , 358
# listing_id , 359
# listing_id , 360
# listing_id , 361
# listing_id , 362
# listing_id , 363
# listing_id , 364
# listing_id , 365
# listing_id , 366
# listing_id , 367
# listing_id , 368
# listing_id , 369
# listing_id , 370
# listing_id , 371
# listing_id , 372
# listing_id , 373
# listing_id , 374
# listing_id , 375
# listing_id , 376
# listing_id , 377
# listing_id , 378
# listing_id , 379
# listing_id , 380
# listing_id , 381
# listing_id , 382
# listing_id , 383
# listing_id , 384
# listing_id , 385
# listing_id , 386
# listing_id , 387
# listing_id , 388
# listing_id , 389
# listing_id , 390
# listing_id , 391
# listing_id , 392
# listing_id , 393
# listing_id , 394
# listing_id , 395
# listing_id , 396
# listing_id , 397
# listing_id , 398
# listing_id , 399
# listing_id , 400
# listing_id , 401
# listing_id , 402
# listing_id , 403
# listing_id , 404
# listing_id , 405
# listing_id , 406
# listing_id , 407
# listing_id , 408
# listing_id , 409
# listing_id , 410
# listing_id , 411
# listing_id , 412
# listing_id , 413
# listing_id , 414
# listing_id , 415
# listing_id , 416
# listing_id , 417
# listing_id , 418
# listing_id , 419
# listing_id , 420
# listing_id , 421
# listing_id , 422
# listing_id , 423
# listing_id , 424
# listing_id , 425
# listing_id , 426
# listing_id , 427
# listing_id , 428
# listing_id , 429
# listing_id , 430
# listing_id , 431
# listing_id , 432
# listing_id , 433
# listing_id , 434
# listing_id , 435
# listing_id , 436
# listing_id , 437
# listing_id , 438
# listing_id , 439
# listing_id , 440
# listing_id , 441
# listing_id , 442
# listing_id , 443
# listing_id , 444
# listing_id , 445
# listing_id , 446
# listing_id , 447
# listing_id , 448
# listing_id , 449
# listing_id , 450
# listing_id , 451
# listing_id , 452
# listing_id , 453
# listing_id , 454
# listing_id , 455
# listing_id , 456
# listing_id , 457
# listing_id , 458
# listing_id , 459
# listing_id , 460
# listing_id , 461
# listing_id , 462
# listing_id , 463
# listing_id , 464
# listing_id , 465
# listing_id , 466
# listing_id , 467
# listing_id , 468
# listing_id , 469
# listing_id , 470
# listing_id , 471
# listing_id , 472
# listing_id , 473
# listing_id , 474
# listing_id , 475
# listing_id , 476
# listing_id , 477
# listing_id , 478
# listing_id , 479
# listing_id , 480
# listing_id , 481
# listing_id , 482
# listing_id , 483
# listing_id , 484
# listing_id , 485
# listing_id , 486
# listing_id , 487
# listing_id , 488
# listing_id , 489
# listing_id , 490
# listing_id , 491
# listing_id , 492
# listing_id , 493
# listing_id , 494
# listing_id , 495
# listing_id , 496
# listing_id , 497
# listing_id , 498
# listing_id , 499
# listing_id , 500
# listing_id , 501
# listing_id , 502
# listing_id , 503
# listing_id , 504
# listing_id , 505
# listing_id , 506
# listing_id , 507
# listing_id , 508
# listing_id , 509
# listing_id , 510
# listing_id , 511
# listing_id , 512
# listing_id , 513
# listing_id , 514
# listing_id , 515
# listing_id , 516
# listing_id , 517
# listing_id , 518
# listing_id , 519
# listing_id , 520
# listing_id , 521
# listing_id , 522
# listing_id , 523
# listing_id , 524
# listing_id , 525
# listing_id , 526
# listing_id , 527
# listing_id , 528
# listing_id , 529
# listing_id , 530
# listing_id , 531
# listing_id , 532
# listing_id , 533
# listing_id , 534
# listing_id , 535
# listing_id , 536
# listing_id , 537
# listing_id , 538
# listing_id , 539
# listing_id , 540
# listing_id , 541
# listing_id , 542
# listing_id , 543
# listing_id , 544
# listing_id , 545
# listing_id , 546
# listing_id , 547
# listing_id , 548
# listing_id , 549
# listing_id , 550
# listing_id , 551
# listing_id , 552
# listing_id , 553
# listing_id , 554
# listing_id , 555
# listing_id , 556
# listing_id , 557
# listing_id , 558
# listing_id , 559
# listing_id , 560
# listing_id , 561
# listing_id , 562
# listing_id , 563
# listing_id , 564
# listing_id , 565
# listing_id , 566
# listing_id , 567
# listing_id , 568
# listing_id , 569
# listing_id , 570
# listing_id , 571
# listing_id , 572
# listing_id , 573
# listing_id , 574
# listing_id , 575
# listing_id , 576
# listing_id , 577
# listing_id , 578
# listing_id , 579
# listing_id , 580
# listing_id , 581
# listing_id , 582
# listing_id , 583
# listing_id , 584
# listing_id , 585
# listing_id , 586
# listing_id , 587
# listing_id , 588
# listing_id , 589
# listing_id , 590
# listing_id , 591
# listing_id , 592
# listing_id , 593
# listing_id , 594
# listing_id , 595
# listing_id , 596
# listing_id , 597
# listing_id , 598
# listing_id , 599
# listing_id , 600
# listing_id , 601
# listing_id , 602
# listing_id , 603
# listing_id , 604
# listing_id , 605
# listing_id , 606
# listing_id , 607
# listing_id , 608
# listing_id , 609
# listing_id , 610
# listing_id , 611
# listing_id , 612
# listing_id , 613
# listing_id , 614
# listing_id , 615
# listing_id , 616
# listing_id , 617
# listing_id , 618
# listing_id , 619
# listing_id , 620
# listing_id , 621
# listing_id , 622
# listing_id , 623
# listing_id , 624
# listing_id , 625
# listing_id , 626
# listing_id , 627
# listing_id , 628
# listing_id , 629
# listing_id , 630
# listing_id , 631
# listing_id , 632
# listing_id , 633
# listing_id , 634
# listing_id , 635
# listing_id , 636
# listing_id , 637
# listing_id , 638
# listing_id , 639
# listing_id , 640
# listing_id , 641
# listing_id , 642
# listing_id , 643
# listing_id , 644
# listing_id , 645
# listing_id , 646
# listing_id , 647
# listing_id , 648
# listing_id , 649
# listing_id , 650
# listing_id , 651
# listing_id , 652
# listing_id , 653
# listing_id , 654
# listing_id , 655
# listing_id , 656
# listing_id , 657
# listing_id , 658
# listing_id , 659
# listing_id , 660
# listing_id , 661
# listing_id , 662
# listing_id , 663
# listing_id , 664
# listing_id , 665
# listing_id , 666
# listing_id , 667
# listing_id , 668
# listing_id , 669
# listing_id , 670
# listing_id , 671
# listing_id , 672
# listing_id , 673
# listing_id , 674
# listing_id , 675
# listing_id , 676
# listing_id , 677
# listing_id , 678
# listing_id , 679
# listing_id , 680
# listing_id , 681
# listing_id , 682
# listing_id , 683
# listing_id , 684
# listing_id , 685
# listing_id , 686
# listing_id , 687
# listing_id , 688
# listing_id , 689
# listing_id , 690
# listing_id , 691
# listing_id , 692
# listing_id , 693
# listing_id , 694
# listing_id , 695
# listing_id , 696
# listing_id , 697
# listing_id , 698
# listing_id , 699
# listing_id , 700
# listing_id , 701
# listing_id , 702
# listing_id , 703
# listing_id , 704
# listing_id , 705
# listing_id , 706
# listing_id , 707
# listing_id , 708
# listing_id , 709
# listing_id , 710
# listing_id , 711
# listing_id , 712
# listing_id , 713
# listing_id , 714
# listing_id , 715
# listing_id , 716
# listing_id , 717
# listing_id , 718
# listing_id , 719
# listing_id , 720
# listing_id , 721
# listing_id , 722
# listing_id , 723
# listing_id , 724
# listing_id , 725
# listing_id , 726
# listing_id , 727
# listing_id , 728
# listing_id , 729
# listing_id , 730
# listing_id , 731
# listing_id , 732
# listing_id , 733
# listing_id , 734
# listing_id , 735
# listing_id , 736
# listing_id , 737
# listing_id , 738
# listing_id , 739
# listing_id , 740
# listing_id , 741
# listing_id , 742
# listing_id , 743
# listing_id , 744
# listing_id , 745
# listing_id , 746
# listing_id , 747
# listing_id , 748
# listing_id , 749
# listing_id , 750
# listing_id , 751
# listing_id , 752
# listing_id , 753
# listing_id , 754
# listing_id , 755
# listing_id , 756
# listing_id , 757
# listing_id , 758
# listing_id , 759
# listing_id , 760
# listing_id , 761
# listing_id , 762
# listing_id , 763
# listing_id , 764
# listing_id , 765
# listing_id , 766
# listing_id , 767
# listing_id , 768
# listing_id , 769
# listing_id , 770
# listing_id , 771
# listing_id , 772
# listing_id , 773
# listing_id , 774
# listing_id , 775
# listing_id , 776
# listing_id , 777
# listing_id , 778
# listing_id , 779
# listing_id , 780
# listing_id , 781
# listing_id , 782
# listing_id , 783
# listing_id , 784
# listing_id , 785
# listing_id , 786
# listing_id , 787
# listing_id , 788
# listing_id , 789
# listing_id , 790
# listing_id , 791
# listing_id , 792
# listing_id , 793
# listing_id , 794
# listing_id , 795
# listing_id , 796
# listing_id , 797
# listing_id , 798
# listing_id , 799
# listing_id , 800
# listing_id , 801
# listing_id , 802
# listing_id , 803
# listing_id , 804
# listing_id , 805
# listing_id , 806
# listing_id , 807
# listing_id , 808
# listing_id , 809
# listing_id , 810
# listing_id , 811
# listing_id , 812
# listing_id , 813
# listing_id , 814
# listing_id , 815
# listing_id , 816
# listing_id , 817
# listing_id , 818
# listing_id , 819
# listing_id , 820
# listing_id , 821
# listing_id , 822
# listing_id , 823
# listing_id , 824
# listing_id , 825
# listing_id , 826
# listing_id , 827
# listing_id , 828
# listing_id , 829
# listing_id , 830
# listing_id , 831
# listing_id , 832
# listing_id , 833
# listing_id , 834
# listing_id , 835
# listing_id , 836
# listing_id , 837
# listing_id , 838
# listing_id , 839
# listing_id , 840
# listing_id , 841
# listing_id , 842
# listing_id , 843
# listing_id , 844
# listing_id , 845
# listing_id , 846
# listing_id , 847
# listing_id , 848
# listing_id , 849
# listing_id , 850
# listing_id , 851
# listing_id , 852
# listing_id , 853
# listing_id , 854
# listing_id , 855
# listing_id , 856
# listing_id , 857
# listing_id , 858
# listing_id , 859
# listing_id , 860
# listing_id , 861
# listing_id , 862
# listing_id , 863
# listing_id , 864
# listing_id , 865
# listing_id , 866
# listing_id , 867
# listing_id , 868
# listing_id , 869
# listing_id , 870
# listing_id , 871
# listing_id , 872
# listing_id , 873
# listing_id , 874
# listing_id , 875
# listing_id , 876
# listing_id , 877
# listing_id , 878
# listing_id , 879
# listing_id , 880
# listing_id , 881
# listing_id , 882
# listing_id , 883
# listing_id , 884
# listing_id , 885
# listing_id , 886
# listing_id , 887
# listing_id , 888
# listing_id , 889
# listing_id , 890
# listing_id , 891
# listing_id , 892
# listing_id , 893
# listing_id , 894
# listing_id , 895
# listing_id , 896
# listing_id , 897
# listing_id , 898
# listing_id , 899
# listing_id , 900
# listing_id , 901
# listing_id , 902
# listing_id , 903
# listing_id , 904
# listing_id , 905
# listing_id , 906
# listing_id , 907
# listing_id , 908
# listing_id , 909
# listing_id , 910
# listing_id , 911
# listing_id , 912
# listing_id , 913
# listing_id , 914
# listing_id , 915
# listing_id , 916
# listing_id , 917
# listing_id , 918
# listing_id , 919
# listing_id , 920
# listing_id , 921
# listing_id , 922
# listing_id , 923
# listing_id , 924
# listing_id , 925
# listing_id , 926
# listing_id , 927
# listing_id , 928
# listing_id , 929
# listing_id , 930
# listing_id , 931
# listing_id , 932
# listing_id , 933
# listing_id , 934
# listing_id , 935
# listing_id , 936
# listing_id , 937
# listing_id , 938
# listing_id , 939
# listing_id , 940
# listing_id , 941
# listing_id , 942
# listing_id , 943
# listing_id , 944
# listing_id , 945
# listing_id , 946
# listing_id , 947
# listing_id , 948
# listing_id , 949
# listing_id , 950
# listing_id , 951
# listing_id , 952
# listing_id , 953
# listing_id , 954
# listing_id , 955
# listing_id , 956
# listing_id , 957
# listing_id , 958
# listing_id , 959
# listing_id , 960
# listing_id , 961
# listing_id , 962
# listing_id , 963
# listing_id , 964
# listing_id , 965
# listing_id , 966
# listing_id , 967
# listing_id , 968
# listing_id , 969
# listing_id , 970
# listing_id , 971
# listing_id , 972
# listing_id , 973
# listing_id , 974
# listing_id , 975
# listing_id , 976
# listing_id , 977
# listing_id , 978
# listing_id , 979
# listing_id , 980
# listing_id , 981
# listing_id , 982
# listing_id , 983
# listing_id , 984
# listing_id , 985
# listing_id , 986
# listing_id , 987
# listing_id , 988
# listing_id , 989
# listing_id , 990
# listing_id , 991
# listing_id , 992
# listing_id , 993
# listing_id , 994
# listing_id , 995
# listing_id , 996
# listing_id , 997
# listing_id , 998
# local_price , 0
# local_price , 1
# local_price , 2
# local_price , 3
# local_price , 4
# local_price , 5
# local_price , 6
# local_price , 7
# local_price , 8
# local_price , 9
# local_price , 10
# local_price , 11
# local_price , 12
# local_price , 13
# local_price , 14
# local_price , 15
# local_price , 16
# local_price , 17
# local_price , 18
# local_price , 19
# local_price , 20
# local_price , 21
# local_price , 22
# local_price , 23
# local_price , 24
# local_price , 25
# local_price , 26
# local_price , 27
# local_price , 28
# local_price , 29
# local_price , 30
# local_price , 31
# local_price , 32
# local_price , 33
# local_price , 34
# local_price , 35
# local_price , 36
# local_price , 37
# local_price , 38
# local_price , 39
# local_price , 40
# local_price , 41
# local_price , 42
# local_price , 43
# local_price , 44
# local_price , 45
# local_price , 46
# local_price , 47
# local_price , 48
# local_price , 49
# local_price , 50
# local_price , 51
# local_price , 52
# local_price , 53
# local_price , 54
# local_price , 55
# local_price , 56
# local_price , 57
# local_price , 58
# local_price , 59
# local_price , 60
# local_price , 61
# local_price , 62
# local_price , 63
# local_price , 64
# local_price , 65
# local_price , 66
# local_price , 67
# local_price , 68
# local_price , 69
# local_price , 70
# local_price , 71
# local_price , 72
# local_price , 73
# local_price , 74
# local_price , 75
# local_price , 76
# local_price , 77
# local_price , 78
# local_price , 79
# local_price , 80
# local_price , 81
# local_price , 82
# local_price , 83
# local_price , 84
# local_price , 85
# local_price , 86
# local_price , 87
# local_price , 88
# local_price , 89
# local_price , 90
# local_price , 91
# local_price , 92
# local_price , 93
# local_price , 94
# local_price , 95
# local_price , 96
# local_price , 97
# local_price , 98
# local_price , 99
# local_price , 100
# local_price , 101
# local_price , 102
# local_price , 103
# local_price , 104
# local_price , 105
# local_price , 106
# local_price , 107
# local_price , 108
# local_price , 109
# local_price , 110
# local_price , 111
# local_price , 112
# local_price , 113
# local_price , 114
# local_price , 115
# local_price , 116
# local_price , 117
# local_price , 118
# local_price , 119
# local_price , 120
# local_price , 121
# local_price , 122
# local_price , 123
# local_price , 124
# local_price , 125
# local_price , 126
# local_price , 127
# local_price , 128
# local_price , 129
# local_price , 130
# local_price , 131
# local_price , 132
# local_price , 133
# local_price , 134
# local_price , 135
# local_price , 136
# local_price , 137
# local_price , 138
# local_price , 139
# local_price , 140
# local_price , 141
# local_price , 142
# local_price , 143
# local_price , 144
# local_price , 145
# local_price , 146
# local_price , 147
# local_price , 148
# local_price , 149
# local_price , 150
# local_price , 151
# local_price , 152
# local_price , 153
# local_price , 154
# local_price , 155
# local_price , 156
# local_price , 157
# local_price , 158
# local_price , 159
# local_price , 160
# local_price , 161
# local_price , 162
# local_price , 163
# local_price , 164
# local_price , 165
# local_price , 166
# local_price , 167
# local_price , 168
# local_price , 169
# local_price , 170
# local_price , 171
# local_price , 172
# local_price , 173
# local_price , 174
# local_price , 175
# local_price , 176
# local_price , 177
# local_price , 178
# local_price , 179
# local_price , 180
# local_price , 181
# local_price , 182
# local_price , 183
# local_price , 184
# local_price , 185
# local_price , 186
# local_price , 187
# local_price , 188
# local_price , 189
# local_price , 190
# local_price , 191
# local_price , 192
# local_price , 193
# local_price , 194
# local_price , 195
# local_price , 196
# local_price , 197
# local_price , 198
# local_price , 199
# local_price , 200
# local_price , 201
# local_price , 202
# local_price , 203
# local_price , 204
# local_price , 205
# local_price , 206
# local_price , 207
# local_price , 208
# local_price , 209
# local_price , 210
# local_price , 211
# local_price , 212
# local_price , 213
# local_price , 214
# local_price , 215
# local_price , 216
# local_price , 217
# local_price , 218
# local_price , 219
# local_price , 220
# local_price , 221
# local_price , 222
# local_price , 223
# local_price , 224
# local_price , 225
# local_price , 226
# local_price , 227
# local_price , 228
# local_price , 229
# local_price , 230
# local_price , 231
# local_price , 232
# local_price , 233
# local_price , 234
# local_price , 235
# local_price , 236
# local_price , 237
# local_price , 238
# local_price , 239
# local_price , 240
# local_price , 241
# local_price , 242
# local_price , 243
# local_price , 244
# local_price , 245
# local_price , 246
# local_price , 247
# local_price , 248
# local_price , 249
# local_price , 250
# local_price , 251
# local_price , 252
# local_price , 253
# local_price , 254
# local_price , 255
# local_price , 256
# local_price , 257
# local_price , 258
# local_price , 259
# local_price , 260
# local_price , 261
# local_price , 262
# local_price , 263
# local_price , 264
# local_price , 265
# local_price , 266
# local_price , 267
# local_price , 268
# local_price , 269
# local_price , 270
# local_price , 271
# local_price , 272
# local_price , 273
# local_price , 274
# local_price , 275
# local_price , 276
# local_price , 277
# local_price , 278
# local_price , 279
# local_price , 280
# local_price , 281
# local_price , 282
# local_price , 283
# local_price , 284
# local_price , 285
# local_price , 286
# local_price , 287
# local_price , 288
# local_price , 289
# local_price , 290
# local_price , 291
# local_price , 292
# local_price , 293
# local_price , 294
# local_price , 295
# local_price , 296
# local_price , 297
# local_price , 298
# local_price , 299
# local_price , 300
# local_price , 301
# local_price , 302
# local_price , 303
# local_price , 304
# local_price , 305
# local_price , 306
# local_price , 307
# local_price , 308
# local_price , 309
# local_price , 310
# local_price , 311
# local_price , 312
# local_price , 313
# local_price , 314
# local_price , 315
# local_price , 316
# local_price , 317
# local_price , 318
# local_price , 319
# local_price , 320
# local_price , 321
# local_price , 322
# local_price , 323
# local_price , 324
# local_price , 325
# local_price , 326
# local_price , 327
# local_price , 328
# local_price , 329
# local_price , 330
# local_price , 331
# local_price , 332
# local_price , 333
# local_price , 334
# local_price , 335
# local_price , 336
# local_price , 337
# local_price , 338
# local_price , 339
# local_price , 340
# local_price , 341
# local_price , 342
# local_price , 343
# local_price , 344
# local_price , 345
# local_price , 346
# local_price , 347
# local_price , 348
# local_price , 349
# local_price , 350
# local_price , 351
# local_price , 352
# local_price , 353
# local_price , 354
# local_price , 355
# local_price , 356
# local_price , 357
# local_price , 358
# local_price , 359
# local_price , 360
# local_price , 361
# local_price , 362
# local_price , 363
# local_price , 364
# local_price , 365
# local_price , 366
# local_price , 367
# local_price , 368
# local_price , 369
# local_price , 370
# local_price , 371
# local_price , 372
# local_price , 373
# local_price , 374
# local_price , 375
# local_price , 376
# local_price , 377
# local_price , 378
# local_price , 379
# local_price , 380
# local_price , 381
# local_price , 382
# local_price , 383
# local_price , 384
# local_price , 385
# local_price , 386
# local_price , 387
# local_price , 388
# local_price , 389
# local_price , 390
# local_price , 391
# local_price , 392
# local_price , 393
# local_price , 394
# local_price , 395
# local_price , 396
# local_price , 397
# local_price , 398
# local_price , 399
# local_price , 400
# local_price , 401
# local_price , 402
# local_price , 403
# local_price , 404
# local_price , 405
# local_price , 406
# local_price , 407
# local_price , 408
# local_price , 409
# local_price , 410
# local_price , 411
# local_price , 412
# local_price , 413
# local_price , 414
# local_price , 415
# local_price , 416
# local_price , 417
# local_price , 418
# local_price , 419
# local_price , 420
# local_price , 421
# local_price , 422
# local_price , 423
# local_price , 424
# local_price , 425
# local_price , 426
# local_price , 427
# local_price , 428
# local_price , 429
# local_price , 430
# local_price , 431
# local_price , 432
# local_price , 433
# local_price , 434
# local_price , 435
# local_price , 436
# local_price , 437
# local_price , 438
# local_price , 439
# local_price , 440
# local_price , 441
# local_price , 442
# local_price , 443
# local_price , 444
# local_price , 445
# local_price , 446
# local_price , 447
# local_price , 448
# local_price , 449
# local_price , 450
# local_price , 451
# local_price , 452
# local_price , 453
# local_price , 454
# local_price , 455
# local_price , 456
# local_price , 457
# local_price , 458
# local_price , 459
# local_price , 460
# local_price , 461
# local_price , 462
# local_price , 463
# local_price , 464
# local_price , 465
# local_price , 466
# local_price , 467
# local_price , 468
# local_price , 469
# local_price , 470
# local_price , 471
# local_price , 472
# local_price , 473
# local_price , 474
# local_price , 475
# local_price , 476
# local_price , 477
# local_price , 478
# local_price , 479
# local_price , 480
# local_price , 481
# local_price , 482
# local_price , 483
# local_price , 484
# local_price , 485
# local_price , 486
# local_price , 487
# local_price , 488
# local_price , 489
# local_price , 490
# local_price , 491
# local_price , 492
# local_price , 493
# local_price , 494
# local_price , 495
# local_price , 496
# local_price , 497
# local_price , 498
# local_price , 499
# local_price , 500
# local_price , 501
# local_price , 502
# local_price , 503
# local_price , 504
# local_price , 505
# local_price , 506
# local_price , 507
# local_price , 508
# local_price , 509
# local_price , 510
# local_price , 511
# local_price , 512
# local_price , 513
# local_price , 514
# local_price , 515
# local_price , 516
# local_price , 517
# local_price , 518
# local_price , 519
# local_price , 520
# local_price , 521
# local_price , 522
# local_price , 523
# local_price , 524
# local_price , 525
# local_price , 526
# local_price , 527
# local_price , 528
# local_price , 529
# local_price , 530
# local_price , 531
# local_price , 532
# local_price , 533
# local_price , 534
# local_price , 535
# local_price , 536
# local_price , 537
# local_price , 538
# local_price , 539
# local_price , 540
# local_price , 541
# local_price , 542
# local_price , 543
# local_price , 544
# local_price , 545
# local_price , 546
# local_price , 547
# local_price , 548
# local_price , 549
# local_price , 550
# local_price , 551
# local_price , 552
# local_price , 553
# local_price , 554
# local_price , 555
# local_price , 556
# local_price , 557
# local_price , 558
# local_price , 559
# local_price , 560
# local_price , 561
# local_price , 562
# local_price , 563
# local_price , 564
# local_price , 565
# local_price , 566
# local_price , 567
# local_price , 568
# local_price , 569
# local_price , 570
# local_price , 571
# local_price , 572
# local_price , 573
# local_price , 574
# local_price , 575
# local_price , 576
# local_price , 577
# local_price , 578
# local_price , 579
# local_price , 580
# local_price , 581
# local_price , 582
# local_price , 583
# local_price , 584
# local_price , 585
# local_price , 586
# local_price , 587
# local_price , 588
# local_price , 589
# local_price , 590
# local_price , 591
# local_price , 592
# local_price , 593
# local_price , 594
# local_price , 595
# local_price , 596
# local_price , 597
# local_price , 598
# local_price , 599
# local_price , 600
# local_price , 601
# local_price , 602
# local_price , 603
# local_price , 604
# local_price , 605
# local_price , 606
# local_price , 607
# local_price , 608
# local_price , 609
# local_price , 610
# local_price , 611
# local_price , 612
# local_price , 613
# local_price , 614
# local_price , 615
# local_price , 616
# local_price , 617
# local_price , 618
# local_price , 619
# local_price , 620
# local_price , 621
# local_price , 622
# local_price , 623
# local_price , 624
# local_price , 625
# local_price , 626
# local_price , 627
# local_price , 628
# local_price , 629
# local_price , 630
# local_price , 631
# local_price , 632
# local_price , 633
# local_price , 634
# local_price , 635
# local_price , 636
# local_price , 637
# local_price , 638
# local_price , 639
# local_price , 640
# local_price , 641
# local_price , 642
# local_price , 643
# local_price , 644
# local_price , 645
# local_price , 646
# local_price , 647
# local_price , 648
# local_price , 649
# local_price , 650
# local_price , 651
# local_price , 652
# local_price , 653
# local_price , 654
# local_price , 655
# local_price , 656
# local_price , 657
# local_price , 658
# local_price , 659
# local_price , 660
# local_price , 661
# local_price , 662
# local_price , 663
# local_price , 664
# local_price , 665
# local_price , 666
# local_price , 667
# local_price , 668
# local_price , 669
# local_price , 670
# local_price , 671
# local_price , 672
# local_price , 673
# local_price , 674
# local_price , 675
# local_price , 676
# local_price , 677
# local_price , 678
# local_price , 679
# local_price , 680
# local_price , 681
# local_price , 682
# local_price , 683
# local_price , 684
# local_price , 685
# local_price , 686
# local_price , 687
# local_price , 688
# local_price , 689
# local_price , 690
# local_price , 691
# local_price , 692
# local_price , 693
# local_price , 694
# local_price , 695
# local_price , 696
# local_price , 697
# local_price , 698
# local_price , 699
# local_price , 700
# local_price , 701
# local_price , 702
# local_price , 703
# local_price , 704
# local_price , 705
# local_price , 706
# local_price , 707
# local_price , 708
# local_price , 709
# local_price , 710
# local_price , 711
# local_price , 712
# local_price , 713
# local_price , 714
# local_price , 715
# local_price , 716
# local_price , 717
# local_price , 718
# local_price , 719
# local_price , 720
# local_price , 721
# local_price , 722
# local_price , 723
# local_price , 724
# local_price , 725
# local_price , 726
# local_price , 727
# local_price , 728
# local_price , 729
# local_price , 730
# local_price , 731
# local_price , 732
# local_price , 733
# local_price , 734
# local_price , 735
# local_price , 736
# local_price , 737
# local_price , 738
# local_price , 739
# local_price , 740
# local_price , 741
# local_price , 742
# local_price , 743
# local_price , 744
# local_price , 745
# local_price , 746
# local_price , 747
# local_price , 748
# local_price , 749
# local_price , 750
# local_price , 751
# local_price , 752
# local_price , 753
# local_price , 754
# local_price , 755
# local_price , 756
# local_price , 757
# local_price , 758
# local_price , 759
# local_price , 760
# local_price , 761
# local_price , 762
# local_price , 763
# local_price , 764
# local_price , 765
# local_price , 766
# local_price , 767
# local_price , 768
# local_price , 769
# local_price , 770
# local_price , 771
# local_price , 772
# local_price , 773
# local_price , 774
# local_price , 775
# local_price , 776
# local_price , 777
# local_price , 778
# local_price , 779
# local_price , 780
# local_price , 781
# local_price , 782
# local_price , 783
# local_price , 784
# local_price , 785
# local_price , 786
# local_price , 787
# local_price , 788
# local_price , 789
# local_price , 790
# local_price , 791
# local_price , 792
# local_price , 793
# local_price , 794
# local_price , 795
# local_price , 796
# local_price , 797
# local_price , 798
# local_price , 799
# local_price , 800
# local_price , 801
# local_price , 802
# local_price , 803
# local_price , 804
# local_price , 805
# local_price , 806
# local_price , 807
# local_price , 808
# local_price , 809
# local_price , 810
# local_price , 811
# local_price , 812
# local_price , 813
# local_price , 814
# local_price , 815
# local_price , 816
# local_price , 817
# local_price , 818
# local_price , 819
# local_price , 820
# local_price , 821
# local_price , 822
# local_price , 823
# local_price , 824
# local_price , 825
# local_price , 826
# local_price , 827
# local_price , 828
# local_price , 829
# local_price , 830
# local_price , 831
# local_price , 832
# local_price , 833
# local_price , 834
# local_price , 835
# local_price , 836
# local_price , 837
# local_price , 838
# local_price , 839
# local_price , 840
# local_price , 841
# local_price , 842
# local_price , 843
# local_price , 844
# local_price , 845
# local_price , 846
# local_price , 847
# local_price , 848
# local_price , 849
# local_price , 850
# local_price , 851
# local_price , 852
# local_price , 853
# local_price , 854
# local_price , 855
# local_price , 856
# local_price , 857
# local_price , 858
# local_price , 859
# local_price , 860
# local_price , 861
# local_price , 862
# local_price , 863
# local_price , 864
# local_price , 865
# local_price , 866
# local_price , 867
# local_price , 868
# local_price , 869
# local_price , 870
# local_price , 871
# local_price , 872
# local_price , 873
# local_price , 874
# local_price , 875
# local_price , 876
# local_price , 877
# local_price , 878
# local_price , 879
# local_price , 880
# local_price , 881
# local_price , 882
# local_price , 883
# local_price , 884
# local_price , 885
# local_price , 886
# local_price , 887
# local_price , 888
# local_price , 889
# local_price , 890
# local_price , 891
# local_price , 892
# local_price , 893
# local_price , 894
# local_price , 895
# local_price , 896
# local_price , 897
# local_price , 898
# local_price , 899
# local_price , 900
# local_price , 901
# local_price , 902
# local_price , 903
# local_price , 904
# local_price , 905
# local_price , 906
# local_price , 907
# local_price , 908
# local_price , 909
# local_price , 910
# local_price , 911
# local_price , 912
# local_price , 913
# local_price , 914
# local_price , 915
# local_price , 916
# local_price , 917
# local_price , 918
# local_price , 919
# local_price , 920
# local_price , 921
# local_price , 922
# local_price , 923
# local_price , 924
# local_price , 925
# local_price , 926
# local_price , 927
# local_price , 928
# local_price , 929
# local_price , 930
# local_price , 931
# local_price , 932
# local_price , 933
# local_price , 934
# local_price , 935
# local_price , 936
# local_price , 937
# local_price , 938
# local_price , 939
# local_price , 940
# local_price , 941
# local_price , 942
# local_price , 943
# local_price , 944
# local_price , 945
# local_price , 946
# local_price , 947
# local_price , 948
# local_price , 949
# local_price , 950
# local_price , 951
# local_price , 952
# local_price , 953
# local_price , 954
# local_price , 955
# local_price , 956
# local_price , 957
# local_price , 958
# local_price , 959
# local_price , 960
# local_price , 961
# local_price , 962
# local_price , 963
# local_price , 964
# local_price , 965
# local_price , 966
# local_price , 967
# local_price , 968
# local_price , 969
# local_price , 970
# local_price , 971
# local_price , 972
# local_price , 973
# local_price , 974
# local_price , 975
# local_price , 976
# local_price , 977
# local_price , 978
# local_price , 979
# local_price , 980
# local_price , 981
# local_price , 982
# local_price , 983
# local_price , 984
# local_price , 985
# local_price , 986
# local_price , 987
# local_price , 988
# local_price , 989
# local_price , 990
# local_price , 991
# local_price , 992
# local_price , 993
# local_price , 994
# local_price , 995
# local_price , 996
# local_price , 997
# local_price , 998
# name , 0
# name , 1
# name , 2
# name , 3
# name , 4
# name , 5
# name , 6
# name , 7
# name , 8
# name , 9
# name , 10
# pricing_monthly_factor , 496
# pricing_monthly_factor , 497
# pricing_monthly_factor , 498
# pricing_monthly_factor , 499
# pricing_monthly_factor , 500
# pricing_monthly_factor , 501
# pricing_monthly_factor , 502
# pricing_monthly_factor , 503
# pricing_monthly_factor , 504
# pricing_monthly_factor , 505
# pricing_monthly_factor , 506
# pricing_monthly_factor , 507
# pricing_monthly_factor , 508
# pricing_monthly_factor , 509
# pricing_monthly_factor , 510
# pricing_monthly_factor , 511
# pricing_monthly_factor , 512
# pricing_monthly_factor , 513
# pricing_monthly_factor , 514
# pricing_monthly_factor , 515
# pricing_monthly_factor , 516
# pricing_monthly_factor , 517
# pricing_monthly_factor , 518
# pricing_monthly_factor , 519
# pricing_monthly_factor , 520
# pricing_monthly_factor , 521
# pricing_monthly_factor , 522
# pricing_monthly_factor , 523
# pricing_monthly_factor , 524
# pricing_monthly_factor , 525
# pricing_monthly_factor , 526
# pricing_monthly_factor , 527
# pricing_monthly_factor , 528
# pricing_monthly_factor , 529
# pricing_monthly_factor , 530
# pricing_monthly_factor , 531
# pricing_monthly_factor , 532
# pricing_monthly_factor , 533
# pricing_monthly_factor , 534
# pricing_monthly_factor , 535
# pricing_monthly_factor , 536
# pricing_monthly_factor , 537
# pricing_monthly_factor , 538
# pricing_monthly_factor , 539
# pricing_monthly_factor , 540
# pricing_monthly_factor , 541
# pricing_monthly_factor , 542
# pricing_monthly_factor , 543
# pricing_monthly_factor , 544
# pricing_monthly_factor , 545
# pricing_monthly_factor , 546
# pricing_monthly_factor , 547
# pricing_monthly_factor , 548
# pricing_monthly_factor , 549
# pricing_monthly_factor , 550
# pricing_monthly_factor , 551
# pricing_monthly_factor , 552
# pricing_monthly_factor , 553
# pricing_monthly_factor , 554
# pricing_monthly_factor , 555
# pricing_monthly_factor , 556
# pricing_monthly_factor , 557
# pricing_monthly_factor , 558
# pricing_monthly_factor , 559
# pricing_monthly_factor , 560
# pricing_monthly_factor , 561
# pricing_monthly_factor , 562
# pricing_monthly_factor , 563
# pricing_monthly_factor , 564
# pricing_monthly_factor , 565
# pricing_monthly_factor , 566
# pricing_monthly_factor , 567
# pricing_monthly_factor , 568
# pricing_monthly_factor , 569
# pricing_monthly_factor , 570
# pricing_monthly_factor , 571
# pricing_monthly_factor , 572
# pricing_monthly_factor , 573
# pricing_monthly_factor , 574
# pricing_monthly_factor , 575
# pricing_monthly_factor , 576
# pricing_monthly_factor , 577
# pricing_monthly_factor , 578
# pricing_monthly_factor , 579
# pricing_monthly_factor , 580
# pricing_monthly_factor , 581
# pricing_monthly_factor , 582
# pricing_monthly_factor , 583
# pricing_monthly_factor , 584
# pricing_monthly_factor , 585
# pricing_monthly_factor , 586
# pricing_monthly_factor , 587
# pricing_monthly_factor , 588
# pricing_monthly_factor , 589
# pricing_monthly_factor , 590
# pricing_monthly_factor , 591
# pricing_monthly_factor , 592
# pricing_monthly_factor , 593
# pricing_monthly_factor , 594
# pricing_monthly_factor , 595
# pricing_monthly_factor , 596
# pricing_monthly_factor , 597
# pricing_monthly_factor , 598
# pricing_monthly_factor , 599
# pricing_monthly_factor , 600
# pricing_monthly_factor , 601
# pricing_monthly_factor , 602
# pricing_monthly_factor , 603
# pricing_monthly_factor , 604
# pricing_monthly_factor , 605
# pricing_monthly_factor , 606
# pricing_monthly_factor , 607
# pricing_monthly_factor , 608
# pricing_monthly_factor , 609
# pricing_monthly_factor , 610
# pricing_monthly_factor , 611
# pricing_monthly_factor , 612
# pricing_monthly_factor , 613
# pricing_monthly_factor , 614
# pricing_monthly_factor , 615
# pricing_monthly_factor , 616
# pricing_monthly_factor , 617
# pricing_monthly_factor , 618
# pricing_monthly_factor , 619
# pricing_monthly_factor , 620
# pricing_monthly_factor , 621
# pricing_monthly_factor , 622
# pricing_monthly_factor , 623
# pricing_monthly_factor , 624
# pricing_monthly_factor , 625
# pricing_monthly_factor , 626
# pricing_monthly_factor , 627
# pricing_monthly_factor , 628
# pricing_monthly_factor , 629
# pricing_monthly_factor , 630
# pricing_monthly_factor , 631
# pricing_monthly_factor , 632
# pricing_monthly_factor , 633
# pricing_monthly_factor , 634
# pricing_monthly_factor , 635
# pricing_monthly_factor , 636
# pricing_monthly_factor , 637
# pricing_monthly_factor , 638
# pricing_monthly_factor , 639
# pricing_monthly_factor , 640
# pricing_monthly_factor , 641
# pricing_monthly_factor , 642
# pricing_monthly_factor , 643
# pricing_monthly_factor , 644
# pricing_monthly_factor , 645
# pricing_monthly_factor , 646
# pricing_monthly_factor , 647
# pricing_monthly_factor , 648
# pricing_monthly_factor , 649
# pricing_monthly_factor , 650
# pricing_monthly_factor , 651
# pricing_monthly_factor , 652
# pricing_monthly_factor , 653
# pricing_monthly_factor , 654
# pricing_monthly_factor , 655
# pricing_monthly_factor , 656
# pricing_monthly_factor , 657
# pricing_monthly_factor , 658
# pricing_monthly_factor , 659
# pricing_monthly_factor , 660
# pricing_monthly_factor , 661
# pricing_monthly_factor , 662
# pricing_monthly_factor , 663
# pricing_monthly_factor , 664
# pricing_monthly_factor , 665
# pricing_monthly_factor , 666
# pricing_monthly_factor , 667
# pricing_monthly_factor , 668
# pricing_monthly_factor , 669
# pricing_monthly_factor , 670
# pricing_monthly_factor , 671
# pricing_monthly_factor , 672
# pricing_monthly_factor , 673
# pricing_monthly_factor , 674
# pricing_monthly_factor , 675
# pricing_monthly_factor , 676
# pricing_monthly_factor , 677
# pricing_monthly_factor , 678
# pricing_monthly_factor , 679
# pricing_monthly_factor , 680
# pricing_monthly_factor , 681
# pricing_monthly_factor , 682
# pricing_monthly_factor , 683
# pricing_monthly_factor , 684
# pricing_monthly_factor , 685
# pricing_monthly_factor , 686
# pricing_monthly_factor , 687
# pricing_monthly_factor , 688
# pricing_monthly_factor , 689
# pricing_monthly_factor , 690
# pricing_monthly_factor , 691
# pricing_monthly_factor , 692
# pricing_monthly_factor , 693
# pricing_monthly_factor , 694
# pricing_monthly_factor , 695
# pricing_monthly_factor , 696
# pricing_monthly_factor , 697
# pricing_monthly_factor , 698
# pricing_monthly_factor , 699
# pricing_monthly_factor , 700
# pricing_monthly_factor , 701
# pricing_monthly_factor , 702
# pricing_monthly_factor , 703
# pricing_monthly_factor , 704
# pricing_monthly_factor , 705
# pricing_monthly_factor , 706
# pricing_monthly_factor , 707
# pricing_monthly_factor , 708
# pricing_monthly_factor , 709
# pricing_monthly_factor , 710
# pricing_monthly_factor , 711
# pricing_monthly_factor , 712
# pricing_monthly_factor , 713
# pricing_monthly_factor , 714
# pricing_monthly_factor , 715
# pricing_monthly_factor , 716
# pricing_monthly_factor , 717
# pricing_monthly_factor , 718
# pricing_monthly_factor , 719
# pricing_monthly_factor , 720
# pricing_monthly_factor , 721
# pricing_monthly_factor , 722
# pricing_monthly_factor , 723
# pricing_monthly_factor , 724
# pricing_monthly_factor , 725
# pricing_monthly_factor , 726
# pricing_monthly_factor , 727
# pricing_monthly_factor , 728
# pricing_monthly_factor , 729
# pricing_monthly_factor , 730
# pricing_monthly_factor , 731
# pricing_monthly_factor , 732
# pricing_monthly_factor , 733
# pricing_monthly_factor , 734
# pricing_monthly_factor , 735
# pricing_monthly_factor , 736
# pricing_monthly_factor , 737
# pricing_monthly_factor , 738
# pricing_monthly_factor , 739
# pricing_monthly_factor , 740
# pricing_monthly_factor , 741
# pricing_monthly_factor , 742
# pricing_monthly_factor , 743
# pricing_monthly_factor , 744
# pricing_monthly_factor , 745
# pricing_monthly_factor , 746
# pricing_monthly_factor , 747
# pricing_monthly_factor , 748
# pricing_monthly_factor , 749
# pricing_monthly_factor , 750
# pricing_monthly_factor , 751
# pricing_monthly_factor , 752
# pricing_monthly_factor , 753
# pricing_monthly_factor , 754
# pricing_monthly_factor , 755
# pricing_monthly_factor , 756
# pricing_monthly_factor , 757
# pricing_monthly_factor , 758
# pricing_monthly_factor , 759
# pricing_monthly_factor , 760
# pricing_monthly_factor , 761
# pricing_monthly_factor , 762
# pricing_monthly_factor , 763
# pricing_monthly_factor , 764
# pricing_monthly_factor , 765
# pricing_monthly_factor , 766
# pricing_monthly_factor , 767
# pricing_monthly_factor , 768
# pricing_monthly_factor , 769
# pricing_monthly_factor , 770
# pricing_monthly_factor , 771
# pricing_monthly_factor , 772
# pricing_monthly_factor , 773
# pricing_monthly_factor , 774
# pricing_monthly_factor , 775
# pricing_monthly_factor , 776
# pricing_monthly_factor , 777
# pricing_monthly_factor , 778
# pricing_monthly_factor , 779
# pricing_monthly_factor , 780
# pricing_monthly_factor , 781
# pricing_monthly_factor , 782
# pricing_monthly_factor , 783
# pricing_monthly_factor , 784
# pricing_monthly_factor , 785
# pricing_monthly_factor , 786
# pricing_monthly_factor , 787
# pricing_monthly_factor , 788
# pricing_monthly_factor , 789
# pricing_monthly_factor , 790
# pricing_monthly_factor , 791
# pricing_monthly_factor , 792
# pricing_monthly_factor , 793
# pricing_monthly_factor , 794
# pricing_monthly_factor , 795
# pricing_monthly_factor , 796
# pricing_monthly_factor , 797
# pricing_monthly_factor , 798
# pricing_monthly_factor , 799
# pricing_monthly_factor , 800
# pricing_monthly_factor , 801
# pricing_monthly_factor , 802
# pricing_monthly_factor , 803
# pricing_monthly_factor , 804
# pricing_monthly_factor , 805
# pricing_monthly_factor , 806
# pricing_monthly_factor , 807
# pricing_monthly_factor , 808
# pricing_monthly_factor , 809
# pricing_monthly_factor , 810
# pricing_monthly_factor , 811
# pricing_monthly_factor , 812
# pricing_monthly_factor , 813
# pricing_monthly_factor , 814
# pricing_monthly_factor , 815
# pricing_monthly_factor , 816
# pricing_monthly_factor , 817
# pricing_monthly_factor , 818
# pricing_monthly_factor , 819
# pricing_monthly_factor , 820
# pricing_monthly_factor , 821
# pricing_monthly_factor , 822
# pricing_monthly_factor , 823
# pricing_monthly_factor , 824
# pricing_monthly_factor , 825
# pricing_monthly_factor , 826
# pricing_monthly_factor , 827
# pricing_monthly_factor , 828
# pricing_monthly_factor , 829
# pricing_monthly_factor , 830
# pricing_monthly_factor , 831
# pricing_monthly_factor , 832
# pricing_monthly_factor , 833
# pricing_monthly_factor , 834
# pricing_monthly_factor , 835
# pricing_monthly_factor , 836
# pricing_monthly_factor , 837
# pricing_monthly_factor , 838
# pricing_monthly_factor , 839
# pricing_monthly_factor , 840
# pricing_monthly_factor , 841
# pricing_monthly_factor , 842
# pricing_monthly_factor , 843
# pricing_monthly_factor , 844
# pricing_monthly_factor , 845
# pricing_monthly_factor , 846
# pricing_monthly_factor , 847
# pricing_monthly_factor , 848
# pricing_monthly_factor , 849
# pricing_monthly_factor , 850
# pricing_monthly_factor , 851
# pricing_monthly_factor , 852
# pricing_monthly_factor , 853
# pricing_monthly_factor , 854
# pricing_monthly_factor , 855
# pricing_monthly_factor , 856
# pricing_monthly_factor , 857
# pricing_monthly_factor , 858
# pricing_monthly_factor , 859
# pricing_monthly_factor , 860
# pricing_monthly_factor , 861
# pricing_monthly_factor , 862
# pricing_monthly_factor , 863
# pricing_monthly_factor , 864
# pricing_monthly_factor , 865
# pricing_monthly_factor , 866
# pricing_monthly_factor , 867
# pricing_monthly_factor , 868
# pricing_monthly_factor , 869
# pricing_monthly_factor , 870
# pricing_monthly_factor , 871
# pricing_monthly_factor , 872
# pricing_monthly_factor , 873
# pricing_monthly_factor , 874
# pricing_monthly_factor , 875
# pricing_monthly_factor , 876
# pricing_monthly_factor , 877
# pricing_monthly_factor , 878
# pricing_monthly_factor , 879
# pricing_monthly_factor , 880
# pricing_monthly_factor , 881
# pricing_monthly_factor , 882
# pricing_monthly_factor , 883
# pricing_monthly_factor , 884
# pricing_monthly_factor , 885
# pricing_monthly_factor , 886
# pricing_monthly_factor , 887
# pricing_monthly_factor , 888
# pricing_monthly_factor , 889
# pricing_monthly_factor , 890
# pricing_monthly_factor , 891
# pricing_monthly_factor , 892
# pricing_monthly_factor , 893
# pricing_monthly_factor , 894
# pricing_monthly_factor , 895
# pricing_monthly_factor , 896
# pricing_monthly_factor , 897
# pricing_monthly_factor , 898
# pricing_monthly_factor , 899
# pricing_monthly_factor , 900
# pricing_monthly_factor , 901
# pricing_monthly_factor , 902
# pricing_monthly_factor , 903
# pricing_monthly_factor , 904
# pricing_monthly_factor , 905
# pricing_monthly_factor , 906
# pricing_monthly_factor , 907
# pricing_monthly_factor , 908
# pricing_monthly_factor , 909
# pricing_monthly_factor , 910
# pricing_monthly_factor , 911
# pricing_monthly_factor , 912
# pricing_monthly_factor , 913
# pricing_monthly_factor , 914
# pricing_monthly_factor , 915
# pricing_monthly_factor , 916
# pricing_monthly_factor , 917
# pricing_monthly_factor , 918
# pricing_monthly_factor , 919
# pricing_monthly_factor , 920
# pricing_monthly_factor , 921
# pricing_monthly_factor , 922
# pricing_monthly_factor , 923
# pricing_monthly_factor , 924
# pricing_monthly_factor , 925
# pricing_monthly_factor , 926
# pricing_monthly_factor , 927
# pricing_monthly_factor , 928
# pricing_monthly_factor , 929
# pricing_monthly_factor , 930
# pricing_monthly_factor , 931
# pricing_monthly_factor , 932
# pricing_monthly_factor , 933
# pricing_monthly_factor , 934
# pricing_monthly_factor , 935
# pricing_monthly_factor , 936
# pricing_monthly_factor , 937
# pricing_monthly_factor , 938
# pricing_monthly_factor , 939
# pricing_monthly_factor , 940
# pricing_monthly_factor , 941
# pricing_monthly_factor , 942
# pricing_monthly_factor , 943
# pricing_monthly_factor , 944
# pricing_monthly_factor , 945
# pricing_monthly_factor , 946
# pricing_monthly_factor , 947
# pricing_monthly_factor , 948
# pricing_monthly_factor , 949
# pricing_monthly_factor , 950
# pricing_monthly_factor , 951
# pricing_monthly_factor , 952
# pricing_monthly_factor , 953
# pricing_monthly_factor , 954
# pricing_monthly_factor , 955
# pricing_monthly_factor , 956
# pricing_monthly_factor , 957
# pricing_monthly_factor , 958
# pricing_monthly_factor , 959
# pricing_monthly_factor , 960
# pricing_monthly_factor , 961
# pricing_monthly_factor , 962
# pricing_monthly_factor , 963
# pricing_monthly_factor , 964
# pricing_monthly_factor , 965
# pricing_monthly_factor , 966
# pricing_monthly_factor , 967
# pricing_monthly_factor , 968
# pricing_monthly_factor , 969
# pricing_monthly_factor , 970
# pricing_monthly_factor , 971
# pricing_monthly_factor , 972
# pricing_monthly_factor , 973
# pricing_monthly_factor , 974
# pricing_monthly_factor , 975
# pricing_monthly_factor , 976
# pricing_monthly_factor , 977
# pricing_monthly_factor , 978
# pricing_monthly_factor , 979
# pricing_monthly_factor , 980
# pricing_monthly_factor , 981
# pricing_monthly_factor , 982
# pricing_monthly_factor , 983
# pricing_monthly_factor , 984
# pricing_monthly_factor , 985
# pricing_monthly_factor , 986
# pricing_monthly_factor , 987
# pricing_monthly_factor , 988
# pricing_monthly_factor , 989
# pricing_monthly_factor , 990
# pricing_monthly_factor , 991
# pricing_monthly_factor , 992
# pricing_monthly_factor , 993
# pricing_monthly_factor , 994
# pricing_monthly_factor , 995
# pricing_monthly_factor , 996
# pricing_monthly_factor , 997
# pricing_monthly_factor , 998
# Number of columns dropped : 0

# %%
class FeatureExtractor:
    """
        Feature Extractor class
    """
    
    def __init__(self, data : pds.DataFrame, flist: list):
        """
            Input : pandas.DataFrame, feature list to drop
            Output : X_train, X_test, y_train, y_test according to sklearn.model_selection.train_test_split
        """
        self.x_train, self.x_test, self.y_train, self.y_test = None, None, None, None
        self.df = data
        self.flist = flist
        
    def split(size: float, random_state :int = 42):
        pass
    
    def train():
        pass
